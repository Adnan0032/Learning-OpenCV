# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL


image = PIL.Image.open("python.png").convert("RGB")
print(image)
image_array = np.asarray(image)
print(image_array.shape)
print(image_array)
print(image_array/255.0)
plt.imshow(image_array, cmap='gray',vmin=0,vmax=255)
# Out:
# <PIL.Image.Image image mode=RGB size=1720x900 at 0x298246D7CA0>
# (900, 1720, 3)
# [[[38 45 61]
#   [38 45 61]
#   [38 45 61]
#   ...
#   [38 45 61]
#   [38 45 61]
#   [38 45 61]]
#
#  [[38 45 61]
#   [38 45 61]
#   [38 45 61]
#   ...
#   [38 45 61]
#   [38 45 61]
#   [38 45 61]]
#
#  [[38 45 61]
#   [38 45 61]
#   [38 45 61]
#   ...
#   [38 45 61]
#   [38 45 61]
#   [38 45 61]]
#
#  ...
#
#  [[38 45 61]
#   [38 45 61]
#   [38 45 61]
#   ...
#   [38 45 61]
#   [38 45 61]
#   [38 45 61]]
#
#  [[38 45 61]
#   [38 45 61]
#   [38 45 61]
#   ...
#   [38 45 61]
#   [38 45 61]
#   [38 45 61]]
#
#  [[38 45 61]
#   [38 45 61]
#   [38 45 61]
#   ...
#   [38 45 61]
#   [38 45 61]
#   [38 45 61]]]
# [[[0.14901961 0.17647059 0.23921569]
#   [0.14901961 0.17647059 0.23921569]
#   [0.14901961 0.17647059 0.23921569]
#   ...
#   [0.14901961 0.17647059 0.23921569]
#   [0.14901961 0.17647059 0.23921569]
#   [0.14901961 0.17647059 0.23921569]]
#
#  [[0.14901961 0.17647059 0.23921569]
# ...

# %%
img_r=image_array.copy()
img_b=image_array.copy()
img_g=image_array.copy()
img_r[:,:,1]=0
img_r[:,:,2]=0

img_g[:,:,0]=0
img_g[:,:,2]=0

img_b[:,:,0]=0
img_b[:,:,1]=0

plt.figure()
plt.imshow(img_r,vmin=0,vmax=255)
plt.figure()
plt.imshow(img_g,vmin=0,vmax=255)
plt.figure()
plt.imshow(img_b,vmin=0,vmax=255)
plt.imshow(image_array ,vmin=0,vmax=255)
